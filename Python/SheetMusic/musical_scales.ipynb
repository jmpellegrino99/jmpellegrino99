# %%
notes = {
    "A": 0
    ,"B-flat": 1
    ,"B": 2
    ,"C": 3
    ,"C-sharp": 4
    ,"D": 5
    ,"E-flat": 6
    ,"E": 7
    ,"F": 8
    ,"F-sharp": 9
    ,"G": 10
    ,"A-flat": 11
}

notes_inverted = {value: key for key, value in notes.items()}

# %%
notes_inverted

for i in range(12):
    print(notes_inverted[i%12], notes_inverted[(i-4)%12], notes_inverted[(i-2)%12], notes_inverted[(i+5)%12])
# Out:
# A F G D
# B-flat F-sharp A-flat E-flat
# B G A E
# C A-flat B-flat F
# C-sharp A B F-sharp
# D B-flat C G
# E-flat B C-sharp A-flat
# E C D A
# F C-sharp E-flat B-flat
# F-sharp D E B
# G E-flat F C
# A-flat E F-sharp C-sharp
